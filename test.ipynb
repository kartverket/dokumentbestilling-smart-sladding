# %%
import model_main

# %%
def get_bounding_boxes():

    docid = '2023_62529_200'

    json_responses = model_main.main(docid)

    return json_responses

# %%
res = get_bounding_boxes()
print(res)
# Out:
# PDF downloaded successfully.
# [{'page': 1, 'height': 288.71999999999997, 'width': 405.0, 'x': 6.4799999999999995, 'y': 23.4}, {'page': 1, 'height': 645.12, 'width': 208.44, 'x': 6.4799999999999995, 'y': 23.04}, {'page': 1, 'height': 660.9599999999999, 'width': 536.4, 'x': 6.4799999999999995, 'y': 23.04}, {'page': 1, 'height': 304.2, 'width': 405.0, 'x': 6.4799999999999995, 'y': 23.759999999999998}, {'page': 1, 'height': 645.12, 'width': 536.4, 'x': 6.4799999999999995, 'y': 23.4}, {'page': 1, 'height': 660.9599999999999, 'width': 208.44, 'x': 6.4799999999999995, 'y': 23.4}, {'page': 2, 'height': 272.15999999999997, 'width': 77.03999999999999, 'x': 6.4799999999999995, 'y': 23.4}, {'page': 2, 'height': 303.84, 'width': 77.03999999999999, 'x': 6.4799999999999995, 'y': 23.04}]
