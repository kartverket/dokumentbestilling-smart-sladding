# %%
import evaluation_main
import evaluation_utils

# %%
config = r'--oem 3 --psm 11'

total_results, total_tp, total_fp, total_fn = evaluation_main.evaluate_model('../dokumenter/', config=config)
# Out:
# 1 0 0
# 0
# 1 0 0
# 1
# 3 0 0
# 2
# 3 0 3
# 3
# 5 0 3
# 4
# 5 0 3
# 5
# 6 0 4
# 6
# 7 0 8
# 7
# 7 0 9
# 8
# 9 0 12
# 9
# 12 0 13
# 10
# 13 0 15
# 11
# 13 0 15
# 12
# 13 0 15
# 13
# 19 0 15
# 14
# 22 0 15
# 15
# 22 0 15
# 16
# 22 0 15
# 17
# 24 0 16
# 18
# 24 0 16
# 19
# 24 0 21
# 20
# 25 0 21
# 21
# 26 0 21
# 22
# 28 0 21
# 23
# 28 0 21
# 24
# 30 0 21
# 25
# 31 0 21
# 26
# 38 0 21
# 27
# 38 0 23
# 28
# 39 0 23
# 29
# 39 0 23
# 30
# 42 0 24
# 31
# 43 0 24
# 32
# 44 0 24
# 33
# 46 0 24
# 34
# 46 0 24
# 35
# 47 0 24
# 36
# 47 0 24
# 37
# 47 0 25
# 38
# 48 0 25
# 39
# 48 0 26
# 40
# 49 0 26
# 41
# 51 0 26
# 42
# 53 0 27
# 43
# 53 0 29
# 44
# 53 0 29
# 45
# 53 0 29
# 46
# 54 0 29
# 47
# 56 0 29
# 48
# 56 0 29
# 49
# 56 0 32
# 50
# 57 0 32
# 51
# 57 0 32
# 52
# 59 0 32
# 53
# 59 0 32
# 54
# 61 0 32
# 55
# 63 0 32
# 56
# 64 0 32
# 57
# 64 0 32
# 58
# 65 0 33
# 59
# 65 0 33
# 60
# 68 0 33
# 61
# 74 0 33
# 62
# 74 0 36
# 63
# 80 0 36
# 64
# 80 0 36
# 65
# 80 0 36
# 66
# 81 0 37
# 67
# ...

# %% [markdown]
# ## RESULTS
#
# Total TP: 929, Total FP: 79, Total FN: 580

# %%
evaluation_utils.get_metrics_and_cm(total_tp, total_fp, total_fn)
# Out:
# Precision: 0.9216269841269841
# Recall: 0.6156394963552021
# F1: 0.7381803734604687
# Accuracy: 0.5850125944584383
